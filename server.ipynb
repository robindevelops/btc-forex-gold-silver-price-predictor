# %% [markdown]
# ## Starting Working with Data Science

# %% [markdown]
# # Os Module

# %%
import os
os.getcwd()
os.listdir()
os.makedirs("new_folder")

# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %%
result = pd.read_csv("coin_Aave.csv")
result.describe
# Out:
# <bound method NDFrame.describe of      SNo  Name Symbol                 Date        High         Low  \
# 0      1  Aave   AAVE  2020-10-05 23:59:59   55.112358   49.787900
# 1      2  Aave   AAVE  2020-10-06 23:59:59   53.402270   40.734578
# 2      3  Aave   AAVE  2020-10-07 23:59:59   42.408314   35.970690
# 3      4  Aave   AAVE  2020-10-08 23:59:59   44.902511   36.696057
# 4      5  Aave   AAVE  2020-10-09 23:59:59   47.569533   43.291776
# 5      6  Aave   AAVE  2020-10-10 23:59:59   51.405655   46.703328
# 6      7  Aave   AAVE  2020-10-11 23:59:59   51.453374   48.716040
# 7      8  Aave   AAVE  2020-10-12 23:59:59   54.421418   48.754077
# 8      9  Aave   AAVE  2020-10-13 23:59:59   57.481904   49.598735
# 9     10  Aave   AAVE  2020-10-14 23:59:59   57.853946   49.629529
# 10    11  Aave   AAVE  2020-10-15 23:59:59   52.080685   44.018325
# 11    12  Aave   AAVE  2020-10-16 23:59:59   43.906730   39.142957
# ...
