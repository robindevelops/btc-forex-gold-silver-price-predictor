# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("coin_Aave.csv")

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# SNo                   int64
# Name                    str
# Symbol                  str
# Date         datetime64[us]
# High                float64
# Low                 float64
# Open                float64
# Close               float64
# Volume              float64
# Marketcap           float64
# dtype: object
